# %%
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json 

from geopy.geocoders import Nominatim 

import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# importing data from csv file...
# generating head of dataframe...
# dataframe consisting of three columns...
df1 = pd.read_csv('Geospatial_Coordinates.csv')
df1.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %%
# printing the number of rows of dataframe based on merged postcode column...
print ('data dimensions:', df1.shape)
# Out:
# data dimensions: (103, 3)

# %%
# replaced column name for consistency while merging two dataframes...
df1.columns = df1.columns.str.replace('Postal Code','postcode')
df1.head(10)
# Out:
#   postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476
# 5      M1J  43.744734 -79.239476
# 6      M1K  43.727929 -79.262029
# 7      M1L  43.711112 -79.284577
# 8      M1M  43.716316 -79.239476
# 9      M1N  43.692657 -79.264848

# %%
# importing previous data from csv file...
# generating head of dataframe...
# dataframe consisting of three columns...
df2 = pd.read_csv('postalcodes_data.csv')
df2.head(10)
# Out:
#   postcode           borough      neighborhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %%
# merging both dataframes...
df1 = df1.merge(df2, on=['postcode'])
df1.head(20)
# Out:
#    postcode   Latitude  Longitude      borough              neighborhood
# 0       M1B  43.806686 -79.194353  Scarborough                     Rouge
# 1       M1B  43.806686 -79.194353  Scarborough                   Malvern
# 2       M1C  43.784535 -79.160497  Scarborough            Highland Creek
# 3       M1C  43.784535 -79.160497  Scarborough                Rouge Hill
# 4       M1C  43.784535 -79.160497  Scarborough                Port Union
# 5       M1E  43.763573 -79.188711  Scarborough                 Guildwood
# 6       M1E  43.763573 -79.188711  Scarborough               Morningside
# 7       M1E  43.763573 -79.188711  Scarborough                 West Hill
# 8       M1G  43.770992 -79.216917  Scarborough                    Woburn
# 9       M1H  43.773136 -79.239476  Scarborough                 Cedarbrae
# 10      M1J  43.744734 -79.239476  Scarborough       Scarborough Village
# 11      M1K  43.727929 -79.262029  Scarborough      East Birchmount Park
# ...

# %%
# grouping columns in order...
df1 = df1.groupby(['postcode', 'borough', 'neighborhood','Latitude','Longitude']).sum()
df1
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
# End.

# %%
# create map
map_clusters = folium.Map(location=[43.686412, -79.416936], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-13c98395be21> in <module>
#      10 # add markers to the map
#      11 markers_colors = []
# ---> 12 for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['neighborhood'], toronto_merged['Cluster Labels']):
#      13     label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
#      14     folium.CircleMarker(
#
# NameError: name 'toronto_merged' is not defined
